# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import sys
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
# !pip install citipy
from citipy import citipy

# Output File (CSV)
output_data_file = r"C:\Users\Kaleb\PycharmProjects\python-api\output_data\cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)
# Out:
# Requirement already satisfied: citipy in c:\users\kaleb\anaconda3\lib\site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in c:\users\kaleb\anaconda3\lib\site-packages (from citipy) (0.16)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 614

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"
query_url = f"{url}appid={weather_api_key}&units={units}&q="
response = requests.get(query_url +"Peoria").json()
response
# Out:
# {'coord': {'lon': -89.77, 'lat': 40.77},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 6.17,
#   'feels_like': 1.13,
#   'temp_min': 5.56,
#   'temp_max': 7,
#   'pressure': 1020,
#   'humidity': 70},
#  'visibility': 10000,
#  'wind': {'speed': 4.6, 'deg': 10},
#  'clouds': {'all': 90},
#  'dt': 1603673612,
#  'sys': {'type': 1,
#   'id': 5354,
#   'country': 'US',
#   'sunrise': 1603628513,
#   'sunset': 1603667042},
#  'timezone': -18000,
#  'id': 4905697,
#  'name': 'Peoria',
#  'cod': 200}

# %%
# set lists for the dataframe
city_two = []
cloudinesses = []
dates = []
humidities = []
lats = []
lngs = []
max_temps = []
wind_speeds = []
countries = []

# set initial count quantities for organization
count_one = 0
set_one = 1

# loops for creating dataframe columns
for city in cities:
    try:
        response = requests.get(query_url + city.replace(" ","&")).json()
        cloudinesses.append(response['clouds']['all'])
        countries.append(response['sys']['country'])
        dates.append(response['dt'])
        humidities.append(response['main']['humidity'])
        lats.append(response['coord']['lat'])
        lngs.append(response['coord']['lon'])
        max_temps.append(response['main']['temp_max'])
        wind_speeds.append(response['wind']['speed'])
        if count_one > 48:
            count_one = 1
            set_one += 1
            city_two.append(city)
        else:
            count_one += 1
            city_two.append(city)
        print(f"Processing Record {count_one} of Set {set_one} | {city}")
    except Exception:
        print("City not found. Skipping...")
print("------------------------------\nData Retrieval Complete\n------------------------------")
# Out:
# Processing Record 1 of Set 1 | vila franca do campo
# Processing Record 2 of Set 1 | fort saint john
# Processing Record 3 of Set 1 | udachnyy
# Processing Record 4 of Set 1 | villa constitucion
# Processing Record 5 of Set 1 | khatanga
# Processing Record 6 of Set 1 | fortuna
# City not found. Skipping...
# Processing Record 7 of Set 1 | yar-sale
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 8 of Set 1 | svatove
# Processing Record 9 of Set 1 | tahara
# Processing Record 10 of Set 1 | bluff
# Processing Record 11 of Set 1 | sao joao da barra
# Processing Record 12 of Set 1 | punta arenas
# City not found. Skipping...
# Processing Record 13 of Set 1 | bogorodskoye
# Processing Record 14 of Set 1 | bengkulu
# Processing Record 15 of Set 1 | nome
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | ulverstone
# Processing Record 18 of Set 1 | east london
# Processing Record 19 of Set 1 | atocha
# Processing Record 20 of Set 1 | pangnirtung
# Processing Record 21 of Set 1 | xuzhou
# Processing Record 22 of Set 1 | cascais
# Processing Record 23 of Set 1 | rio gallegos
# Processing Record 24 of Set 1 | ganzhou
# Processing Record 25 of Set 1 | lebu
# Processing Record 26 of Set 1 | ribeira grande
# Processing Record 27 of Set 1 | ushuaia
# Processing Record 28 of Set 1 | busselton
# Processing Record 29 of Set 1 | mitchelstown
# Processing Record 30 of Set 1 | mantua
# Processing Record 31 of Set 1 | arman
# Processing Record 32 of Set 1 | albany
# Processing Record 33 of Set 1 | kahului
# Processing Record 34 of Set 1 | hilo
# Processing Record 35 of Set 1 | guerrero negro
# Processing Record 36 of Set 1 | arraial do cabo
# Processing Record 37 of Set 1 | hobart
# City not found. Skipping...
# Processing Record 38 of Set 1 | kiunga
# City not found. Skipping...
# Processing Record 39 of Set 1 | san nicolas
# Processing Record 40 of Set 1 | cape town
# Processing Record 41 of Set 1 | puerto ayora
# Processing Record 42 of Set 1 | chokurdakh
# Processing Record 43 of Set 1 | pimenta bueno
# Processing Record 44 of Set 1 | ruteng
# Processing Record 45 of Set 1 | lethem
# Processing Record 46 of Set 1 | nanortalik
# Processing Record 47 of Set 1 | tasiilaq
# Processing Record 48 of Set 1 | cap malheureux
# Processing Record 49 of Set 1 | havre-saint-pierre
# Processing Record 1 of Set 2 | san cristobal
# Processing Record 2 of Set 2 | komsomolskiy
# Processing Record 3 of Set 2 | hithadhoo
# Processing Record 4 of Set 2 | kavieng
# Processing Record 5 of Set 2 | kapaa
# Processing Record 6 of Set 2 | barrow
# Processing Record 7 of Set 2 | katsuura
# Processing Record 8 of Set 2 | arys
# City not found. Skipping...
# Processing Record 9 of Set 2 | vostok
# Processing Record 10 of Set 2 | isla mujeres
# Processing Record 11 of Set 2 | faanui
# City not found. Skipping...
# Processing Record 12 of Set 2 | evensk
# Processing Record 13 of Set 2 | clyde river
# Processing Record 14 of Set 2 | andenes
# Processing Record 15 of Set 2 | codrington
# Processing Record 16 of Set 2 | torrevieja
# Processing Record 17 of Set 2 | alofi
# Processing Record 18 of Set 2 | atuona
# Processing Record 19 of Set 2 | vaini
# City not found. Skipping...
# Processing Record 20 of Set 2 | saint-philippe
# City not found. Skipping...
# Processing Record 21 of Set 2 | salalah
# Processing Record 22 of Set 2 | iwanai
# Processing Record 23 of Set 2 | yellowknife
# Processing Record 24 of Set 2 | maloh
# Processing Record 25 of Set 2 | cabedelo
# Processing Record 26 of Set 2 | mikkeli
# Processing Record 27 of Set 2 | port elizabeth
# Processing Record 28 of Set 2 | praia
# Processing Record 29 of Set 2 | mar del plata
# Processing Record 30 of Set 2 | luanda
# Processing Record 31 of Set 2 | mataura
# Processing Record 32 of Set 2 | bredasdorp
# Processing Record 33 of Set 2 | poplar bluff
# City not found. Skipping...
# Processing Record 34 of Set 2 | beringovskiy
# Processing Record 35 of Set 2 | luderitz
# Processing Record 36 of Set 2 | george town
# City not found. Skipping...
# Processing Record 37 of Set 2 | nizwa
# City not found. Skipping...
# Processing Record 38 of Set 2 | charters towers
# Processing Record 39 of Set 2 | san felipe
# Processing Record 40 of Set 2 | provideniya
# Processing Record 41 of Set 2 | baruun-urt
# Processing Record 42 of Set 2 | havelock
# Processing Record 43 of Set 2 | abu dhabi
# Processing Record 44 of Set 2 | tsimlyansk
# Processing Record 45 of Set 2 | agirish
# Processing Record 46 of Set 2 | georgetown
# Processing Record 47 of Set 2 | brazzaville
# City not found. Skipping...
# Processing Record 48 of Set 2 | severo-kurilsk
# City not found. Skipping...
# Processing Record 49 of Set 2 | morondava
# Processing Record 1 of Set 3 | grindavik
# Processing Record 2 of Set 3 | nacala
# Processing Record 3 of Set 3 | amga
# Processing Record 4 of Set 3 | port alfred
# Processing Record 5 of Set 3 | coquimbo
# Processing Record 6 of Set 3 | erzurum
# Processing Record 7 of Set 3 | qaanaaq
# Processing Record 8 of Set 3 | korla
# Processing Record 9 of Set 3 | gamba
# Processing Record 10 of Set 3 | bayir
# Processing Record 11 of Set 3 | sinnamary
# City not found. Skipping...
# Processing Record 12 of Set 3 | touros
# Processing Record 13 of Set 3 | jamestown
# Processing Record 14 of Set 3 | port shepstone
# Processing Record 15 of Set 3 | kloulklubed
# Processing Record 16 of Set 3 | liwale
# Processing Record 17 of Set 3 | butaritari
# Processing Record 18 of Set 3 | cherskiy
# Processing Record 19 of Set 3 | hermanus
# Processing Record 20 of Set 3 | dikson
# City not found. Skipping...
# Processing Record 21 of Set 3 | upernavik
# Processing Record 22 of Set 3 | sur
# Processing Record 23 of Set 3 | forio
# Processing Record 24 of Set 3 | kaitangata
# Processing Record 25 of Set 3 | victoria
# Processing Record 26 of Set 3 | samarai
# Processing Record 27 of Set 3 | taoudenni
# City not found. Skipping...
# Processing Record 28 of Set 3 | mys shmidta
# Processing Record 29 of Set 3 | sidney
# City not found. Skipping...
# Processing Record 30 of Set 3 | brae
# Processing Record 31 of Set 3 | berlevag
# Processing Record 32 of Set 3 | bambous virieux
# Processing Record 33 of Set 3 | sola
# Processing Record 34 of Set 3 | coahuayana
# Processing Record 35 of Set 3 | port-gentil
# Processing Record 36 of Set 3 | aklavik
# Processing Record 37 of Set 3 | hamilton
# Processing Record 38 of Set 3 | bolshevik
# Processing Record 39 of Set 3 | thompson
# Processing Record 40 of Set 3 | ketchikan
# Processing Record 41 of Set 3 | simbahan
# Processing Record 42 of Set 3 | requena
# Processing Record 43 of Set 3 | gimli
# Processing Record 44 of Set 3 | flinders
# Processing Record 45 of Set 3 | benjamin hill
# Processing Record 46 of Set 3 | klaksvik
# Processing Record 47 of Set 3 | ancud
# Processing Record 48 of Set 3 | shimoda
# Processing Record 49 of Set 3 | san jose
# City not found. Skipping...
# Processing Record 1 of Set 4 | bathsheba
# Processing Record 2 of Set 4 | tuktoyaktuk
# Processing Record 3 of Set 4 | beloha
# Processing Record 4 of Set 4 | kaman
# Processing Record 5 of Set 4 | iqaluit
# Processing Record 6 of Set 4 | mulbagal
# Processing Record 7 of Set 4 | margate
# Processing Record 8 of Set 4 | marietta
# Processing Record 9 of Set 4 | fagernes
# Processing Record 10 of Set 4 | nikki
# Processing Record 11 of Set 4 | fairbanks
# Processing Record 12 of Set 4 | kalmunai
# Processing Record 13 of Set 4 | erenhot
# Processing Record 14 of Set 4 | sanmenxia
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 15 of Set 4 | puerto rondon
# Processing Record 16 of Set 4 | uyemskiy
# Processing Record 17 of Set 4 | forestville
# Processing Record 18 of Set 4 | pingliang
# Processing Record 19 of Set 4 | suoyarvi
# Processing Record 20 of Set 4 | ponta do sol
# City not found. Skipping...
# Processing Record 21 of Set 4 | iquitos
# Processing Record 22 of Set 4 | kenora
# Processing Record 23 of Set 4 | urumqi
# Processing Record 24 of Set 4 | tombouctou
# Processing Record 25 of Set 4 | grand river south east
# Processing Record 26 of Set 4 | barbastro
# Processing Record 27 of Set 4 | yulara
# Processing Record 28 of Set 4 | kaeo
# Processing Record 29 of Set 4 | chapais
# Processing Record 30 of Set 4 | vanimo
# Processing Record 31 of Set 4 | kiama
# Processing Record 32 of Set 4 | skjervoy
# Processing Record 33 of Set 4 | mirnyy
# Processing Record 34 of Set 4 | stokmarknes
# Processing Record 35 of Set 4 | ozinki
# Processing Record 36 of Set 4 | goderich
# Processing Record 37 of Set 4 | buraydah
# Processing Record 38 of Set 4 | torbay
# Processing Record 39 of Set 4 | namibe
# Processing Record 40 of Set 4 | paranaiba
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 41 of Set 4 | nishihara
# City not found. Skipping...
# Processing Record 42 of Set 4 | hammerfest
# City not found. Skipping...
# Processing Record 43 of Set 4 | nioro
# Processing Record 44 of Set 4 | sopotnica
# Processing Record 45 of Set 4 | bayamo
# Processing Record 46 of Set 4 | carnarvon
# Processing Record 47 of Set 4 | wilmington
# Processing Record 48 of Set 4 | katangli
# Processing Record 49 of Set 4 | tarko-sale
# Processing Record 1 of Set 5 | souillac
# Processing Record 2 of Set 5 | sobolevo
# Processing Record 3 of Set 5 | lompoc
# Processing Record 4 of Set 5 | sovetskaya gavan
# Processing Record 5 of Set 5 | nizhniy baskunchak
# Processing Record 6 of Set 5 | biak
# Processing Record 7 of Set 5 | kyabe
# Processing Record 8 of Set 5 | bilma
# Processing Record 9 of Set 5 | nador
# Processing Record 10 of Set 5 | belmonte
# City not found. Skipping...
# Processing Record 11 of Set 5 | tukrah
# Processing Record 12 of Set 5 | khovu-aksy
# Processing Record 13 of Set 5 | rawson
# Processing Record 14 of Set 5 | mahibadhoo
# City not found. Skipping...
# Processing Record 15 of Set 5 | plainview
# Processing Record 16 of Set 5 | yarmouth
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 17 of Set 5 | vao
# City not found. Skipping...
# Processing Record 18 of Set 5 | sokoto
# Processing Record 19 of Set 5 | bozuyuk
# Processing Record 20 of Set 5 | melnikovo
# Processing Record 21 of Set 5 | goma
# Processing Record 22 of Set 5 | banda aceh
# Processing Record 23 of Set 5 | jian
# Processing Record 24 of Set 5 | norman wells
# Processing Record 25 of Set 5 | surok
# Processing Record 26 of Set 5 | dongying
# Processing Record 27 of Set 5 | nanfeng
# Processing Record 28 of Set 5 | mujiayingzi
# Processing Record 29 of Set 5 | chara
# Processing Record 30 of Set 5 | sambava
# Processing Record 31 of Set 5 | sterling
# Processing Record 32 of Set 5 | avarua
# Processing Record 33 of Set 5 | new norfolk
# Processing Record 34 of Set 5 | puerto palomas
# Processing Record 35 of Set 5 | ilulissat
# Processing Record 36 of Set 5 | bandar
# Processing Record 37 of Set 5 | kapiri mposhi
# Processing Record 38 of Set 5 | balikpapan
# Processing Record 39 of Set 5 | zhigansk
# Processing Record 40 of Set 5 | bethel
# Processing Record 41 of Set 5 | nelidovo
# Processing Record 42 of Set 5 | hasaki
# Processing Record 43 of Set 5 | sunland park
# Processing Record 44 of Set 5 | barraute
# Processing Record 45 of Set 5 | athabasca
# Processing Record 46 of Set 5 | muscat
# Processing Record 47 of Set 5 | esperance
# Processing Record 48 of Set 5 | biltine
# Processing Record 49 of Set 5 | mount gambier
# Processing Record 1 of Set 6 | burnie
# Processing Record 2 of Set 6 | lavrentiya
# Processing Record 3 of Set 6 | laguna
# Processing Record 4 of Set 6 | fegyvernek
# Processing Record 5 of Set 6 | makakilo city
# Processing Record 6 of Set 6 | xunchang
# Processing Record 7 of Set 6 | novita
# Processing Record 8 of Set 6 | manokwari
# Processing Record 9 of Set 6 | krapivinskiy
# Processing Record 10 of Set 6 | filingue
# Processing Record 11 of Set 6 | cayenne
# Processing Record 12 of Set 6 | sao filipe
# City not found. Skipping...
# Processing Record 13 of Set 6 | setermoen
# Processing Record 14 of Set 6 | newport
# Processing Record 15 of Set 6 | kulykivka
# City not found. Skipping...
# Processing Record 16 of Set 6 | alekseyevsk
# Processing Record 17 of Set 6 | emet
# Processing Record 18 of Set 6 | longyearbyen
# Processing Record 19 of Set 6 | saint-joseph
# Processing Record 20 of Set 6 | aswan
# Processing Record 21 of Set 6 | malakal
# Processing Record 22 of Set 6 | caceres
# City not found. Skipping...
# Processing Record 23 of Set 6 | tacoronte
# Processing Record 24 of Set 6 | port macquarie
# Processing Record 25 of Set 6 | dingle
# Processing Record 26 of Set 6 | adrar
# Processing Record 27 of Set 6 | saldanha
# Processing Record 28 of Set 6 | mirganj
# Processing Record 29 of Set 6 | iskateley
# Processing Record 30 of Set 6 | porangatu
# Processing Record 31 of Set 6 | chokwe
# Processing Record 32 of Set 6 | san antonio
# Processing Record 33 of Set 6 | pandan
# Processing Record 34 of Set 6 | reitz
# Processing Record 35 of Set 6 | talnakh
# Processing Record 36 of Set 6 | telimele
# City not found. Skipping...
# Processing Record 37 of Set 6 | puerto madryn
# Processing Record 38 of Set 6 | carballo
# Processing Record 39 of Set 6 | kodino
# Processing Record 40 of Set 6 | anadyr
# Processing Record 41 of Set 6 | atasu
# Processing Record 42 of Set 6 | sioux lookout
# Processing Record 43 of Set 6 | ler
# Processing Record 44 of Set 6 | tymovskoye
# Processing Record 45 of Set 6 | khandyga
# City not found. Skipping...
# Processing Record 46 of Set 6 | kifri
# Processing Record 47 of Set 6 | bukoba
# Processing Record 48 of Set 6 | egvekinot
# Processing Record 49 of Set 6 | concordia
# Processing Record 1 of Set 7 | castro
# Processing Record 2 of Set 7 | hambantota
# Processing Record 3 of Set 7 | tarakan
# Processing Record 4 of Set 7 | yarada
# Processing Record 5 of Set 7 | chuy
# Processing Record 6 of Set 7 | mahebourg
# Processing Record 7 of Set 7 | san patricio
# Processing Record 8 of Set 7 | neftcala
# Processing Record 9 of Set 7 | makokou
# Processing Record 10 of Set 7 | isangel
# Processing Record 11 of Set 7 | axim
# Processing Record 12 of Set 7 | srednekolymsk
# Processing Record 13 of Set 7 | makamba
# City not found. Skipping...
# Processing Record 14 of Set 7 | buin
# Processing Record 15 of Set 7 | faya
# City not found. Skipping...
# Processing Record 16 of Set 7 | mount isa
# Processing Record 17 of Set 7 | vraca
# Processing Record 18 of Set 7 | constitucion
# Processing Record 19 of Set 7 | guanare
# Processing Record 20 of Set 7 | champerico
# Processing Record 21 of Set 7 | myanaung
# Processing Record 22 of Set 7 | kabinda
# Processing Record 23 of Set 7 | zhezkazgan
# Processing Record 24 of Set 7 | moose factory
# Processing Record 25 of Set 7 | caravelas
# Processing Record 26 of Set 7 | karratha
# City not found. Skipping...
# Processing Record 27 of Set 7 | atbasar
# City not found. Skipping...
# Processing Record 28 of Set 7 | cukai
# Processing Record 29 of Set 7 | tuatapere
# Processing Record 30 of Set 7 | airai
# Processing Record 31 of Set 7 | karatau
# Processing Record 32 of Set 7 | eyl
# Processing Record 33 of Set 7 | chulucanas
# Processing Record 34 of Set 7 | nikolskoye
# Processing Record 35 of Set 7 | smithfield
# Processing Record 36 of Set 7 | khani
# City not found. Skipping...
# Processing Record 37 of Set 7 | bartica
# Processing Record 38 of Set 7 | voyvozh
# Processing Record 39 of Set 7 | rexburg
# Processing Record 40 of Set 7 | jumla
# Processing Record 41 of Set 7 | pangai
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 42 of Set 7 | bagnacavallo
# Processing Record 43 of Set 7 | pevek
# Processing Record 44 of Set 7 | kirakira
# Processing Record 45 of Set 7 | omboue
# Processing Record 46 of Set 7 | kodiak
# Processing Record 47 of Set 7 | leningradskiy
# Processing Record 48 of Set 7 | maceio
# Processing Record 49 of Set 7 | bur gabo
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 1 of Set 8 | hokitika
# Processing Record 2 of Set 8 | reo
# Processing Record 3 of Set 8 | daru
# Processing Record 4 of Set 8 | valdivia
# Processing Record 5 of Set 8 | kalach-na-donu
# Processing Record 6 of Set 8 | pont-rouge
# Processing Record 7 of Set 8 | bukachacha
# Processing Record 8 of Set 8 | port lincoln
# Processing Record 9 of Set 8 | narsaq
# Processing Record 10 of Set 8 | geraldton
# Processing Record 11 of Set 8 | kjollefjord
# Processing Record 12 of Set 8 | san lazaro
# Processing Record 13 of Set 8 | muisne
# Processing Record 14 of Set 8 | raga
# Processing Record 15 of Set 8 | miles city
# Processing Record 16 of Set 8 | lata
# Processing Record 17 of Set 8 | ostrovnoy
# Processing Record 18 of Set 8 | kimbe
# Processing Record 19 of Set 8 | nago
# Processing Record 20 of Set 8 | khasan
# Processing Record 21 of Set 8 | longford
# Processing Record 22 of Set 8 | sitka
# Processing Record 23 of Set 8 | lamar
# Processing Record 24 of Set 8 | udomlya
# Processing Record 25 of Set 8 | bundaberg
# Processing Record 26 of Set 8 | college
# Processing Record 27 of Set 8 | morant bay
# Processing Record 28 of Set 8 | sangar
# Processing Record 29 of Set 8 | yauya
# Processing Record 30 of Set 8 | chebsara
# City not found. Skipping...
# Processing Record 31 of Set 8 | pauini
# City not found. Skipping...
# Processing Record 32 of Set 8 | mareeba
# Processing Record 33 of Set 8 | nyaunglebin
# Processing Record 34 of Set 8 | hovd
# Processing Record 35 of Set 8 | tiksi
# Processing Record 36 of Set 8 | bourail
# Processing Record 37 of Set 8 | inhambane
# Processing Record 38 of Set 8 | iralaya
# Processing Record 39 of Set 8 | chanika
# Processing Record 40 of Set 8 | challapata
# Processing Record 41 of Set 8 | ranong
# Processing Record 42 of Set 8 | port augusta
# Processing Record 43 of Set 8 | ahome
# Processing Record 44 of Set 8 | itarema
# Processing Record 45 of Set 8 | myitkyina
# Processing Record 46 of Set 8 | sulangan
# Processing Record 47 of Set 8 | bonnyville
# Processing Record 48 of Set 8 | tutoia
# Processing Record 49 of Set 8 | ust-omchug
# Processing Record 1 of Set 9 | lorengau
# Processing Record 2 of Set 9 | dong hoi
# City not found. Skipping...
# Processing Record 3 of Set 9 | cabo san lucas
# City not found. Skipping...
# Processing Record 4 of Set 9 | itoman
# Processing Record 5 of Set 9 | ouesso
# Processing Record 6 of Set 9 | cockburn town
# Processing Record 7 of Set 9 | paamiut
# Processing Record 8 of Set 9 | gambela
# Processing Record 9 of Set 9 | inongo
# Processing Record 10 of Set 9 | fukue
# Processing Record 11 of Set 9 | caborca
# Processing Record 12 of Set 9 | pemangkat
# Processing Record 13 of Set 9 | kushmurun
# Processing Record 14 of Set 9 | pontes e lacerda
# Processing Record 15 of Set 9 | katherine
# Processing Record 16 of Set 9 | luwuk
# Processing Record 17 of Set 9 | vallenar
# Processing Record 18 of Set 9 | chunoyar
# Processing Record 19 of Set 9 | san quintin
# City not found. Skipping...
# Processing Record 20 of Set 9 | san vicente
# Processing Record 21 of Set 9 | gat
# Processing Record 22 of Set 9 | kihei
# Processing Record 23 of Set 9 | fairview
# Processing Record 24 of Set 9 | sukhumi
# Processing Record 25 of Set 9 | port hedland
# Processing Record 26 of Set 9 | emerald
# Processing Record 27 of Set 9 | lagoa
# Processing Record 28 of Set 9 | sao miguel do araguaia
# Processing Record 29 of Set 9 | masakin
# Processing Record 30 of Set 9 | beaverlodge
# Processing Record 31 of Set 9 | husavik
# Processing Record 32 of Set 9 | saint-denis
# Processing Record 33 of Set 9 | kushiro
# Processing Record 34 of Set 9 | nelson bay
# Processing Record 35 of Set 9 | tiznit
# Processing Record 36 of Set 9 | pringsewu
# Processing Record 37 of Set 9 | mehamn
# Processing Record 38 of Set 9 | cidreira
# Processing Record 39 of Set 9 | jatai
# Processing Record 40 of Set 9 | shakawe
# Processing Record 41 of Set 9 | palu
# Processing Record 42 of Set 9 | tilichiki
# Processing Record 43 of Set 9 | baltay
# Processing Record 44 of Set 9 | camacha
# Processing Record 45 of Set 9 | chimbote
# Processing Record 46 of Set 9 | azul
# Processing Record 47 of Set 9 | kruisfontein
# Processing Record 48 of Set 9 | darhan
# Processing Record 49 of Set 9 | deputatskiy
# Processing Record 1 of Set 10 | dubai
# Processing Record 2 of Set 10 | asyut
# Processing Record 3 of Set 10 | byron bay
# Processing Record 4 of Set 10 | palora
# Processing Record 5 of Set 10 | kribi
# Processing Record 6 of Set 10 | wajir
# Processing Record 7 of Set 10 | nakamura
# City not found. Skipping...
# Processing Record 8 of Set 10 | yerbogachen
# Processing Record 9 of Set 10 | choya
# Processing Record 10 of Set 10 | kodinsk
# Processing Record 11 of Set 10 | dudinka
# Processing Record 12 of Set 10 | pisco
# Processing Record 13 of Set 10 | nandurbar
# Processing Record 14 of Set 10 | novaya zaimka
# Processing Record 15 of Set 10 | filadelfia
# Processing Record 16 of Set 10 | villamontes
# Processing Record 17 of Set 10 | severskaya
# Processing Record 18 of Set 10 | lafiagi
# City not found. Skipping...
# Processing Record 19 of Set 10 | ponta delgada
# Processing Record 20 of Set 10 | alta floresta
# Processing Record 21 of Set 10 | callaway
# Processing Record 22 of Set 10 | lasa
# Processing Record 23 of Set 10 | olovyannaya
# Processing Record 24 of Set 10 | palana
# Processing Record 25 of Set 10 | san luis
# Processing Record 26 of Set 10 | saint-pierre
# City not found. Skipping...
# Processing Record 27 of Set 10 | birao
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 28 of Set 10 | garowe
# Processing Record 29 of Set 10 | howard springs
# City not found. Skipping...
# Processing Record 30 of Set 10 | okha
# Processing Record 31 of Set 10 | odda
# Processing Record 32 of Set 10 | griffith
# Processing Record 33 of Set 10 | bandarbeyla
# Processing Record 34 of Set 10 | sanok
# Processing Record 35 of Set 10 | jalu
# City not found. Skipping...
# Processing Record 36 of Set 10 | mehriz
# Processing Record 37 of Set 10 | hobyo
# Processing Record 38 of Set 10 | chongwe
# Processing Record 39 of Set 10 | misratah
# Processing Record 40 of Set 10 | comodoro rivadavia
# Processing Record 41 of Set 10 | preobrazheniye
# Processing Record 42 of Set 10 | belint
# Processing Record 43 of Set 10 | jeremie
# Processing Record 44 of Set 10 | waren
# Processing Record 45 of Set 10 | duluth
# Processing Record 46 of Set 10 | umea
# Processing Record 47 of Set 10 | sorland
# Processing Record 48 of Set 10 | arlit
# Processing Record 49 of Set 10 | olafsvik
# Processing Record 1 of Set 11 | roald
# Processing Record 2 of Set 11 | aktau
# Processing Record 3 of Set 11 | aleksandrov gay
# City not found. Skipping...
# Processing Record 4 of Set 11 | shakhovskaya
# City not found. Skipping...
# Processing Record 5 of Set 11 | ginda
# Processing Record 6 of Set 11 | atherton
# Processing Record 7 of Set 11 | bull savanna
# Processing Record 8 of Set 11 | wanning
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 9 of Set 11 | tezu
# Processing Record 10 of Set 11 | hinche
# Processing Record 11 of Set 11 | enterprise
# Processing Record 12 of Set 11 | dicabisagan
# Processing Record 13 of Set 11 | saskylakh
# Processing Record 14 of Set 11 | baykit
# Processing Record 15 of Set 11 | lakes entrance
# Processing Record 16 of Set 11 | salinopolis
# Processing Record 17 of Set 11 | mayo
# Processing Record 18 of Set 11 | bafoulabe
# Processing Record 19 of Set 11 | hirtshals
# Processing Record 20 of Set 11 | kilindoni
# Processing Record 21 of Set 11 | santa catarina de tepehuanes
# Processing Record 22 of Set 11 | sarankhola
# City not found. Skipping...
# Processing Record 23 of Set 11 | cuencame
# Processing Record 24 of Set 11 | karera
# Processing Record 25 of Set 11 | ejura
# City not found. Skipping...
# Processing Record 26 of Set 11 | manado
# Processing Record 27 of Set 11 | namie
# Processing Record 28 of Set 11 | diffa
# Processing Record 29 of Set 11 | senneterre
# Processing Record 30 of Set 11 | shieli
# Processing Record 31 of Set 11 | kendari
# Processing Record 32 of Set 11 | north branch
# Processing Record 33 of Set 11 | awjilah
# Processing Record 34 of Set 11 | nivala
# Processing Record 35 of Set 11 | galle
# Processing Record 36 of Set 11 | hull
# Processing Record 37 of Set 11 | bubaque
# Processing Record 38 of Set 11 | ocos
# Processing Record 39 of Set 11 | ouadda
# Processing Record 40 of Set 11 | riyadh
# Processing Record 41 of Set 11 | guaymas
# Processing Record 42 of Set 11 | ukiah
# Processing Record 43 of Set 11 | camamu
# Processing Record 44 of Set 11 | kholodnyy
# Processing Record 45 of Set 11 | primo tapia
# Processing Record 46 of Set 11 | tourlaville
# Processing Record 47 of Set 11 | vestmanna
# Processing Record 48 of Set 11 | tingi
# Processing Record 49 of Set 11 | surskoye
# Processing Record 1 of Set 12 | najran
# Processing Record 2 of Set 12 | juegang
# Processing Record 3 of Set 12 | surt
# Processing Record 4 of Set 12 | poya
# Processing Record 5 of Set 12 | san rafael
# City not found. Skipping...
# Processing Record 6 of Set 12 | mahina
# Processing Record 7 of Set 12 | ust-nera
# Processing Record 8 of Set 12 | leh
# Processing Record 9 of Set 12 | payakumbuh
# Processing Record 10 of Set 12 | springville
# ------------------------------
# Data Retrieval Complete
# ------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_dict = {
    "City":city_two,
    "Cloudiness": cloudinesses,
    "Country": countries,
    "Date": dates,
    "Humidity": humidities,
    "Lat": lats,
    "Lng":lngs,
    "Max Temp":max_temps,
    "Wind Speed":wind_speeds
}

# %%
weather_dataframe = pd.DataFrame(weather_dict)

# %%
weather_dataframe.head()
# Out:
#                    City  Cloudiness Country        Date  Humidity    Lat  \
# 0  vila franca do campo         100      PT  1603673837        95  42.03
# 1       fort saint john          98      NL  1603673837        91  52.65
# 2              udachnyy           0      RU  1603673837        84  66.42
# 3    villa constitucion          97      IT  1603673838        92  46.20
# 4              khatanga          95      RU  1603673838        95  71.97
#
#       Lng  Max Temp  Wind Speed
# 0   -8.16      6.67        2.68
# 1    6.39     10.00        1.34
# 2  112.40    -18.00        1.00
# 3   10.13     11.67        1.17
# 4  102.50    -14.48        4.38

# %%
weather_dataframe.to_csv(output_data_file)

# %%
weather_dataframe.count()
# Out:
# City          549
# Cloudiness    549
# Country       549
# Date          549
# Humidity      549
# Lat           549
# Lng           549
# Max Temp      549
# Wind Speed    549
# dtype: int64

# %%
weather_dataframe.head()
# Out:
#                    City  Cloudiness Country        Date  Humidity    Lat  \
# 0  vila franca do campo         100      PT  1603673837        95  42.03
# 1       fort saint john          98      NL  1603673837        91  52.65
# 2              udachnyy           0      RU  1603673837        84  66.42
# 3    villa constitucion          97      IT  1603673838        92  46.20
# 4              khatanga          95      RU  1603673838        95  71.97
#
#       Lng  Max Temp  Wind Speed
# 0   -8.16      6.67        2.68
# 1    6.39     10.00        1.34
# 2  112.40    -18.00        1.00
# 3   10.13     11.67        1.17
# 4  102.50    -14.48        4.38

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
excess_humidity = weather_dataframe.loc[weather_dataframe["Humidity"] > 100]
excess_humidity.count()
# Out:
# City          0
# Cloudiness    0
# Country       0
# Date          0
# Humidity      0
# Lat           0
# Lng           0
# Max Temp      0
# Wind Speed    0
# dtype: int64

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(weather_dataframe["Lat"],weather_dataframe["Max Temp"], 
            edgecolors="black", facecolors="skyblue")
plt.title('City Latitude vs. Max Tempurature')
plt.xlabel("Latitude")
plt.ylabel("Max Tempurature (C)")
plt.style.use("classic")
plt.grid()
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(weather_dataframe['Lat'], weather_dataframe['Humidity'],
            edgecolors="black", facecolors="skyblue")
plt.title("City Latitude vs. Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.grid()
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_dataframe["Lat"], weather_dataframe["Cloudiness"],
            edgecolors="black", facecolors="skyblue")
plt.title("Latitude vs. Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.grid()
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_dataframe['Lat'], weather_dataframe['Wind Speed'], 
            edgecolors="black", facecolors="skyblue")
plt.title("Latitude vs. Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.grid()
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
L=0
Northern= weather_dataframe.query(f"Lat >= {L}")
Southern= weather_dataframe.query(f"Lat <= {L}")

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = Northern["Lat"]
y_values = Northern["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y= " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.scatter(x_values, y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,-10), fontsize=15,color="blue")
plt.title("Latitude vs. Max Temperature (Northern Hemisphere)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature")
plt.style.use("classic")
R2="R^2"+str(round(rvalue,4))
plt.annotate(R2,(0,-20), fontsize=15, color='blue')
print(f"The correlation coefficient(R^2) is:{rvalue}")
plt.show()
# Out:
# The correlation coefficient(R^2) is:-0.8833616341497225

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = Southern["Lat"]
y_values = Southern["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y= " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.scatter(x_values, y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,35), fontsize=15,color="blue")
plt.title("Latitude vs. Max Temperature (Southern Hemisphere)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature")
plt.style.use("classic")
R2="R^2"+str(round(rvalue,4))
plt.annotate(R2,(-50,30), fontsize=15, color='blue')
print(f"The correlation coefficient(R^2) is:{rvalue}")
plt.show()
# Out:
# The correlation coefficient(R^2) is:0.7191323515809871

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = Northern["Lat"]
y_values = Northern["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y= " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.scatter(x_values, y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(60,10), fontsize=15,color="blue")
plt.title("Latitude vs. Humidity (Northern Hemisphere)")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.style.use("classic")
R2="R^2"+str(round(rvalue,4))
plt.annotate(R2,(60,20), fontsize=15, color='blue')
print(f"The correlation coefficient(R^2) is:{rvalue}")
plt.show()
# Out:
# The correlation coefficient(R^2) is:0.3668518835894299

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = Southern["Lat"]
y_values = Southern["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y= " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.scatter(x_values, y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,35), fontsize=15,color="blue")
plt.title("Latitude vs. Humidity (Southern Hemisphere)")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.style.use("classic")
R2="R^2"+str(round(rvalue,4))
plt.annotate(R2,(-50,42), fontsize=15, color='blue')
print(f"The correlation coefficient(R^2) is:{rvalue}")
plt.show()
# Out:
# The correlation coefficient(R^2) is:0.1965568485110256

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = Northern["Lat"]
y_values = Northern["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y= " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.scatter(x_values, y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,-10), fontsize=15,color="blue")
plt.title("Latitude vs. Cloudiness (Northern Hemisphere)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.style.use("classic")
R2="R^2"+str(round(rvalue,4))
plt.annotate(R2,(50,-10), fontsize=15, color='blue')
print(f"The correlation coefficient(R^2) is:{rvalue}")
plt.show()
# Out:
# The correlation coefficient(R^2) is:0.2700083667918394

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = Southern["Lat"]
y_values = Southern["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y= " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.scatter(x_values, y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-60,-10), fontsize=15,color="blue")
plt.title("Latitude vs. Cloudiness (Southern Hemisphere)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature")
plt.style.use("classic")
R2="R^2"+str(round(rvalue,4))
plt.annotate(R2,(-30,-10), fontsize=15, color='blue')
print(f"The correlation coefficient(R^2) is:{rvalue}")
plt.show()
# Out:
# The correlation coefficient(R^2) is:0.2261210013556566

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = Northern["Lat"]
y_values = Northern["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y= " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.scatter(x_values, y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-10,20), fontsize=15,color="blue")
plt.title("Latitude vs. Wind Speed (Northern Hemisphere)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.style.use("classic")
R2="R^2"+str(round(rvalue,4))
plt.annotate(R2,(-10,23), fontsize=15, color='blue')
print(f"The correlation coefficient(R^2) is:{rvalue}")
plt.show()
# Out:
# The correlation coefficient(R^2) is:0.21160325812861414

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = Southern["Lat"]
y_values = Southern["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y= " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.scatter(x_values, y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-58,-1), fontsize=15,color="blue")
plt.title("Latitude vs. Wind Speed (Southern Hemisphere)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.style.use("classic")
R2="R^2"+str(round(rvalue,4))
plt.annotate(R2,(-20,-1), fontsize=15, color='blue')
print(f"The correlation coefficient(R^2) is:{rvalue}")
plt.show()
# Out:
# The correlation coefficient(R^2) is:-0.3001592494090311

# %%
# ANALYSIS OF DATA
# 1. There is a clear correlation between Max Temp and the distnace away from the equator.  
# As  you move further away from the equator, the max temperature drops 

# 2.  Cloudiness seems to not have a trend based on latitude.  It is an evenly distributed weather pattern.  

# 3. The Northern Hemisphere has less variance in wind speeds than the southern hemisphere.
